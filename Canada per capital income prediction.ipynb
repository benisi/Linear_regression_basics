# %%
import numpy
import pandas
from sklearn import linear_model
import matplotlib.pyplot as plot

# %%
dataframe = pandas.read_csv('Canada_per_capital_income.csv')
dataframe.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plot.xlabel('Year')
plot.ylabel('Per capita income (US$)')
plot.scatter(dataframe.year, dataframe['per capita income (US$)'], marker="x")

# %%
regression = linear_model.LinearRegression()
regression.fit(dataframe[['year']], dataframe['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
regression.predict([[2020]])
# Out:
# array([41288.69409442])
